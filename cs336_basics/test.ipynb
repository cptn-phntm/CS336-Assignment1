# %%
import pickle
vocab, merges = pickle.load(open("../model/bpe_openwebtext_vocab_merges.pkl", "rb"))

# %%
print(sorted(vocab.values(), key=len, reverse=True)[:10])
# Out:
# [b'---------------------------', b'-------------------------', b'-----------------------', b'---------------------', b' disproportionately', b' telecommunications', b'-------------------', b' environmentalists', b' -----------------', b' responsibilities']
